# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Fariya</b><br>
# Data Analyst

# %% [markdown]
# <em>I am interested in data science because it is one of the in-demand professions related to my current field of study. The field has use in almost every other occupation and hence equips its learners with useful set of skills that can give them an edge in their career.</em>

# %% [markdown]
# ### The code in cell 5 is supposed to return an output upon execution. I have defined a simple function that takes in a number and returns its square.  So when called inside the print statement the result of the function is displayed as an output.

# %%
def square(x):
    return x*x
print(square(4))
# Out:
# 16

# %% [markdown]
# <hr>
# <ul>
#     <del><li>This marks the end of this section</li></del>
#     <li>If you are peer assessing this notebook then you probably haven't attempted the final quiz yet.</li>
#     <li>So best of luck!</li>
# </ul>
